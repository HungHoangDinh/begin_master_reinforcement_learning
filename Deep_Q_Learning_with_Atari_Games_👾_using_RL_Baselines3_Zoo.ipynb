# %% [markdown]
# <a href="https://colab.research.google.com/github/HungHoangDinh/begin_master_reinforcement_learning/blob/main/Deep_Q_Learning_with_Atari_Games_%F0%9F%91%BE_using_RL_Baselines3_Zoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# ...
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-907_67f_
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-907_67f_
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit d42f9159bfa897871ea912a8ef5ccc92ba364948
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 25.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (754 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121852 files and directories currently installed.)
# ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# ...
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
# ...

# %% [markdown]
# # Create a virtual display 🔽

# %%
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# E: Unable to locate package python-opengl
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# ...

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# # Train our Deep Q-Learning Agent to Play Space Invaders 👾

# %% [markdown]
# ### Create a hyperparameter config file that will contain our training hyperparameters called dqn.yml.

# %%
# !nvidia-smi
# Out:
# Mon Mar  2 14:10:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ale-py

# %%
# create dqn.yml
with open('dqn.yml', 'w') as f:
    f.write(parameter)

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.83e+03 |
# |    ep_rew_mean      | 355      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2620     |
# |    fps              | 258      |
# |    time_elapsed     | 2138     |
# |    total_timesteps  | 552524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 113130   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.83e+03 |
# |    ep_rew_mean      | 356      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2624     |
# |    fps              | 258      |
# |    time_elapsed     | 2141     |
# |    total_timesteps  | 553460   |
# ...

# %% [markdown]
# # Publish our trained model on the Hub 🚀

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()

# %%
# !pip install stable-baselines3[extra] gymnasium[atari] imageio imageio-ffmpeg

# %%
import gymnasium as gym
import imageio
from stable_baselines3 import DQN
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
import ale_py

gym.register_envs(ale_py)
# ===== Load model =====
model = DQN.load(
    "logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip"
)

# ===== Create original Atari env (Gymnasium version) =====
def make_env():

    env = gym.make("ALE/SpaceInvaders-v5", render_mode="rgb_array")
    env = AtariWrapper(env)
    return env

env = DummyVecEnv([make_env])
env = VecFrameStack(env, n_stack=4)

obs = env.reset()
frames = []

for _ in range(5000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)

    frame = env.envs[0].render()
    frames.append(frame)

    if done:
        break

env.close()

imageio.mimsave("dqn_space_invaders_demo.mp4", frames, fps=30)

print("Video saved!")
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Video saved!

# %%
from huggingface_hub import HfApi, create_repo, upload_file

repo_id = "hunghd20012003/dqn-SpaceInvaders"
model_path = "logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip"

create_repo(repo_id, exist_ok=True)

upload_file(
    path_or_fileobj=model_path,
    path_in_repo="SpaceInvadersNoFrameskip-v4.zip",
    repo_id=repo_id,
)

print("Done!")
# Out:
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
# New Data Upload               : |          |  0.00B /  0.00B
#   ...nvadersNoFrameskip-v4.zip:   3%|2         |  805kB / 27.3MB
# Done!

# %%
from huggingface_hub import upload_file

upload_file(
    path_or_fileobj="dqn_space_invaders_demo.mp4",
    path_in_repo="dqn_space_invaders_demo.mp4",
    repo_id="hunghd20012003/dqn-SpaceInvaders",
)

print("Video uploaded!")
# Out:
# Video uploaded!

# %%
readme_content = f"""
---
library_name: stable-baselines3
tags:
- dqn
- reinforcement-learning
- atari
- space-invaders
---

# 🎮 DQN - Space Invaders

This model was trained using DQN on Atari environment.

## 📺 Demo Video

<video controls width="600">
  <source src="dqn_space_invaders_demo.mp4" type="video/mp4">
</video>

## 🧠 Model Info

- Algorithm: DQN
- Frames stacked: 4
- Timesteps: 1e6
- Environment: SpaceInvadersNoFrameskip-v4

Game:

Space Invaders (Atari 2600)

"""

with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme_content)

upload_file(
    path_or_fileobj="README.md",
    path_in_repo="README.md",
    repo_id=repo_id,
)

print("README uploaded")
print("✅ DONE - Check your Hugging Face repo!")
# Out:
# README uploaded
# ✅ DONE - Check your Hugging Face repo!
